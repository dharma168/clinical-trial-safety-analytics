# %%
import pandas as pd
import pyreadstat

ex, meta = pyreadstat.read_sas7bdat("C:/Users/dharm/Clinical_Trial_SDTM_Project/raw_data/ex.sas7bdat")

print(ex.head())
# Out:
#                        PROJ_ID SITE_ID     SUBID  STATE  EVENT_NO   EVENT_ID  \
# 0  DN-101 Protocol No. 011-007     507  507-0011    5.0       4.1  Cycle #01
# 1  DN-101 Protocol No. 011-007     507  507-0011    5.0       4.2  Cycle #02
# 2  DN-101 Protocol No. 011-007     524  524-0002    5.0       4.1  Cycle #01
# 3  DN-101 Protocol No. 011-007     524  524-0002    5.0       4.2  Cycle #02
# 4  DN-101 Protocol No. 011-007     524  524-0002    5.0       4.3  Cycle #03
#
#              ID  EXFDT_  EXLDT_  EXDOSE  ...  EXTETX  EXOTHTX  EXOTH  \
# 0  2.991875e+09     2.0    16.0     2.0  ...     NaN      NaN    1.0
# 1  3.745599e+09    30.0    44.0     3.0  ...     NaN      NaN    NaN
# 2  2.943304e+09     4.0    19.0     3.0  ...     NaN      NaN    NaN
# 3  3.443567e+09    32.0   151.0     3.0  ...     NaN      1.0    NaN
# 4  3.650105e+09   165.0   179.0     3.0  ...     NaN      NaN    NaN
#
#                          EXOTHSP  EXPD EXPDGI  EXPDTE  EXPDOT  EXPDOTH  \
# ...

# %%
ex.columns.tolist()
# Out:
# ['PROJ_ID',
#  'SITE_ID',
#  'SUBID',
#  'STATE',
#  'EVENT_NO',
#  'EVENT_ID',
#  'ID',
#  'EXFDT_',
#  'EXLDT_',
#  'EXDOSE',
#  'EXDELYN',
#  'EXGITX',
#  'EXTETX',
#  'EXOTHTX',
#  'EXOTH',
#  'EXOTHSP',
#  'EXPD',
#  'EXPDGI',
#  'EXPDTE',
#  'EXPDOT',
#  'EXPDOTH',
#  'EXPDOSP']

# %%
ex.columns
# Out:
# Index(['PROJ_ID', 'SITE_ID', 'SUBID', 'STATE', 'EVENT_NO', 'EVENT_ID', 'ID',
#        'EXFDT_', 'EXLDT_', 'EXDOSE', 'EXDELYN', 'EXGITX', 'EXTETX', 'EXOTHTX',
#        'EXOTH', 'EXOTHSP', 'EXPD', 'EXPDGI', 'EXPDTE', 'EXPDOT', 'EXPDOTH',
#        'EXPDOSP'],
#       dtype='str')

# %%
ex["SUBID"].nunique()
# Out:
# 2

# %%
ex["EXDOSE"].describe()
# Out:
# count    7.000000
# mean     2.857143
# std      0.377964
# min      2.000000
# 25%      3.000000
# 50%      3.000000
# 75%      3.000000
# max      3.000000
# Name: EXDOSE, dtype: float64

# %%
ex["EXGITX"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
ex["EXTETX"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
ex[["EXFDT_", "EXLDT_"]].head()
# Out:
#    EXFDT_  EXLDT_
# 0     2.0    16.0
# 1    30.0    44.0
# 2     4.0    19.0
# 3    32.0   151.0
# 4   165.0   179.0
